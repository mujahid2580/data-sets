# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import scipy

# %%
import pandas_profiling

# %%
import seaborn as sns

# %%
bi=pd.read_csv("https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/AW_BikeBuyer.csv")
bi
# Out:
#        CustomerID  BikeBuyer
# 0           11000          0
# 1           11001          1
# 2           11002          0
# 3           11003          0
# 4           11004          1
# ...           ...        ...
# 16514       13121          0
# 16515       26100          0
# 16516       11328          0
# 16517       23077          0
# 16518       18982          0
#
# [16519 rows x 2 columns]

# %%
bi.head()
# Out:
#    CustomerID  BikeBuyer
# 0       11000          0
# 1       11001          1
# 2       11002          0
# 3       11003          0
# 4       11004          1

# %%
bi.tail()
# Out:
#        CustomerID  BikeBuyer
# 16514       13121          0
# 16515       26100          0
# 16516       11328          0
# 16517       23077          0
# 16518       18982          0

# %%
bi.describe()
# Out:
#          CustomerID     BikeBuyer
# count  16519.000000  16519.000000
# mean   20234.225195      0.332284
# std     5342.515987      0.471046
# min    11000.000000      0.000000
# 25%    15604.500000      0.000000
# 50%    20221.000000      0.000000
# 75%    24860.500000      1.000000
# max    29482.000000      1.000000

# %%
bi.index
# Out:
# RangeIndex(start=0, stop=16519, step=1)

# %%
bi.columns
# Out:
# Index(['CustomerID', 'BikeBuyer'], dtype='object')

# %%
bi.size
# Out:
# 33038

# %%
bi.shape
# Out:
# (16519, 2)

# %%
bi.ndim
# Out:
# 2

# %%
bi.dtypes
# Out:
# CustomerID    int64
# BikeBuyer     int64
# dtype: object

# %%
bi.isnull()
# Out:
#        CustomerID  BikeBuyer
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False
# ...           ...        ...
# 16514       False      False
# 16515       False      False
# 16516       False      False
# 16517       False      False
# 16518       False      False
#
# [16519 rows x 2 columns]

# %%
bi.isna()
# Out:
#        CustomerID  BikeBuyer
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False
# ...           ...        ...
# 16514       False      False
# 16515       False      False
# 16516       False      False
# 16517       False      False
# 16518       False      False
#
# [16519 rows x 2 columns]

# %%
bi.notna()
# Out:
#        CustomerID  BikeBuyer
# 0            True       True
# 1            True       True
# 2            True       True
# 3            True       True
# 4            True       True
# ...           ...        ...
# 16514        True       True
# 16515        True       True
# 16516        True       True
# 16517        True       True
# 16518        True       True
#
# [16519 rows x 2 columns]

# %%
bi.notnull()
# Out:
#        CustomerID  BikeBuyer
# 0            True       True
# 1            True       True
# 2            True       True
# 3            True       True
# 4            True       True
# ...           ...        ...
# 16514        True       True
# 16515        True       True
# 16516        True       True
# 16517        True       True
# 16518        True       True
#
# [16519 rows x 2 columns]

# %%
bi.isna().sum()
# Out:
# CustomerID    0
# BikeBuyer     0
# dtype: int64

# %%
sns.heatmap(bi.corr())

# %%
pandas_profiling.ProfileReport(bi)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
sns.pairplot(bi)
